# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
# names of columns
cols_names = ['Class', 'age', 'menopause', 'tumor-size', 
              'inv-nodes', 'node-caps', 'deg-malig', 'breast', 
              'breast-quad', 'irradiat']

# read the data
df = (pd.read_csv('data/brc/breast-cancer.data', header=None, names=cols_names).replace({'?': 'unknown'}))  # NaN are represented by '?'

# %%
df.head(10)
# Out:
#                   Class    age menopause tumor-size inv-nodes node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
# 5  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 6  no-recurrence-events  50-59   premeno      25-29       0-2        no
# 7  no-recurrence-events  60-69      ge40      20-24       0-2        no
# 8  no-recurrence-events  40-49   premeno      50-54       0-2        no
# 9  no-recurrence-events  40-49   premeno      20-24       0-2        no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# 3          2  right     left_up       no
# 4          2  right   right_low       no
# 5          2   left    left_low       no
# 6          2   left    left_low       no
# 7          1   left    left_low       no
# 8          2   left    left_low       no
# 9          2  right     left_up       no

# %%
X = df.drop(['Class'],axis = 1)
y = df['Class'].copy()

# %%
X.head(10)
# Out:
#    age menopause tumor-size inv-nodes node-caps  deg-malig breast breast-quad  \
# 0    1   premeno      30-34       0-2        no          3   left    left_low
# 1    2   premeno      20-24       0-2        no          2  right    right_up
# 2    2   premeno      20-24       0-2        no          2   left    left_low
# 3    4      ge40      15-19       0-2        no          2  right     left_up
# 4    2   premeno        0-4       0-2        no          2  right   right_low
# 5    4      ge40      15-19       0-2        no          2   left    left_low
# 6    3   premeno      25-29       0-2        no          2   left    left_low
# 7    4      ge40      20-24       0-2        no          1   left    left_low
# 8    2   premeno      50-54       0-2        no          2   left    left_low
# 9    2   premeno      20-24       0-2        no          2  right     left_up
#
#   irradiat  menopause_ge40  menopause_lt40  menopause_premeno
# 0       no               0               0                  1
# 1       no               0               0                  1
# 2       no               0               0                  1
# 3       no               1               0                  0
# 4       no               0               0                  1
# 5       no               1               0                  0
# 6       no               0               0                  1
# 7       no               1               0                  0
# 8       no               0               0                  1
# 9       no               0               0                  1

# %%
le_age = LabelEncoder()

# %%
le_age.fit(df['age'])
# Out:
# LabelEncoder()

# %%
list(le_age.classes_)
# Out:
# ['20-29', '30-39', '40-49', '50-59', '60-69', '70-79']

# %%
le_age.transform(df['age'])
# Out:
# array([1, 2, 2, 4, 2, 4, 3, 4, 2, 2, 2, 3, 4, 3, 2, 4, 2, 3, 4, 3, 3, 4, 1,
#        3, 3, 2, 3, 4, 2, 4, 3, 3, 3, 3, 3, 1, 3, 3, 2, 2, 3, 4, 4, 2, 3, 3,
#        2, 3, 2, 2, 3, 1, 3, 5, 5, 5, 3, 3, 4, 4, 2, 2, 3, 0, 2, 2, 2, 3, 3,
#        4, 4, 2, 4, 3, 1, 3, 3, 1, 3, 2, 3, 4, 4, 3, 2, 3, 4, 5, 3, 2, 1, 3,
#        3, 4, 3, 2, 4, 4, 2, 1, 2, 3, 3, 2, 2, 2, 2, 1, 2, 4, 3, 3, 2, 2, 2,
#        3, 1, 2, 1, 4, 4, 3, 3, 3, 4, 5, 1, 1, 3, 2, 2, 2, 2, 3, 4, 1, 1, 2,
#        1, 2, 3, 3, 4, 2, 4, 2, 4, 3, 1, 3, 3, 4, 3, 4, 1, 4, 3, 3, 3, 2, 2,
#        2, 4, 4, 4, 2, 2, 2, 3, 2, 1, 1, 4, 3, 3, 2, 2, 4, 3, 2, 2, 2, 2, 3,
#        3, 2, 3, 4, 2, 3, 2, 2, 3, 1, 3, 3, 3, 2, 3, 3, 4, 3, 2, 3, 3, 1, 3,
#        3, 3, 2, 2, 3, 2, 3, 4, 2, 3, 2, 4, 1, 2, 1, 4, 4, 1, 2, 2, 3, 4, 4,
#        3, 2, 1, 5, 4, 3, 2, 2, 1, 2, 4, 2, 3, 3, 2, 1, 1, 3, 4, 1, 2, 2, 1,
#        4, 2, 2, 2, 2, 3, 3, 4, 2, 4, 3, 3, 1, 2, 4, 1, 2, 3, 3, 2, 4, 4, 2,
#        1, 4, 3, 3, 3, 1, 1, 4, 2, 3])

# %%
X['age'] = le_age.transform(df['age'])

# %%
X.head(10)
# Out:
#    age menopause tumor-size inv-nodes node-caps  deg-malig breast breast-quad  \
# 0    1   premeno      30-34       0-2        no          3   left    left_low
# 1    2   premeno      20-24       0-2        no          2  right    right_up
# 2    2   premeno      20-24       0-2        no          2   left    left_low
# 3    4      ge40      15-19       0-2        no          2  right     left_up
# 4    2   premeno        0-4       0-2        no          2  right   right_low
# 5    4      ge40      15-19       0-2        no          2   left    left_low
# 6    3   premeno      25-29       0-2        no          2   left    left_low
# 7    4      ge40      20-24       0-2        no          1   left    left_low
# 8    2   premeno      50-54       0-2        no          2   left    left_low
# 9    2   premeno      20-24       0-2        no          2  right     left_up
#
#   irradiat
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# 5       no
# 6       no
# 7       no
# 8       no
# 9       no

# %%
list(le_age.inverse_transform(X.age))
# Out:
# ['30-39',
#  '40-49',
#  '40-49',
#  '60-69',
#  '40-49',
#  '60-69',
#  '50-59',
#  '60-69',
#  '40-49',
#  '40-49',
#  '40-49',
#  '50-59',
#  '60-69',
#  '50-59',
#  '40-49',
#  '60-69',
#  '40-49',
#  '50-59',
#  '60-69',
#  '50-59',
#  '50-59',
#  '60-69',
#  '30-39',
#  '50-59',
#  '50-59',
#  '40-49',
#  '50-59',
#  '60-69',
#  '40-49',
#  '60-69',
#  '50-59',
#  '50-59',
#  '50-59',
#  '50-59',
#  '50-59',
#  '30-39',
#  '50-59',
#  '50-59',
#  '40-49',
#  '40-49',
#  '50-59',
#  '60-69',
#  '60-69',
#  '40-49',
#  '50-59',
#  '50-59',
#  '40-49',
#  '50-59',
#  '40-49',
#  '40-49',
#  '50-59',
#  '30-39',
#  '50-59',
#  '70-79',
#  '70-79',
#  '70-79',
#  '50-59',
#  '50-59',
#  '60-69',
#  '60-69',
#  '40-49',
#  '40-49',
#  '50-59',
#  '20-29',
#  '40-49',
#  '40-49',
#  '40-49',
#  '50-59',
#  '50-59',
#  '60-69',
#  '60-69',
#  '40-49',
#  '60-69',
#  '50-59',
#  '30-39',
#  '50-59',
#  '50-59',
#  '30-39',
#  '50-59',
#  '40-49',
#  '50-59',
#  '60-69',
#  '60-69',
#  '50-59',
#  '40-49',
#  '50-59',
#  '60-69',
#  '70-79',
#  '50-59',
#  '40-49',
#  '30-39',
#  '50-59',
#  '50-59',
#  '60-69',
#  '50-59',
#  '40-49',
#  '60-69',
#  '60-69',
#  '40-49',
#  '30-39',
#  '40-49',
#  '50-59',
#  '50-59',
#  '40-49',
#  '40-49',
#  '40-49',
#  '40-49',
#  '30-39',
#  '40-49',
#  '60-69',
#  '50-59',
#  '50-59',
#  '40-49',
#  '40-49',
#  '40-49',
#  '50-59',
#  '30-39',
#  '40-49',
#  '30-39',
#  '60-69',
#  '60-69',
#  '50-59',
#  '50-59',
#  '50-59',
#  '60-69',
#  '70-79',
#  '30-39',
#  '30-39',
#  '50-59',
#  '40-49',
#  '40-49',
#  '40-49',
#  '40-49',
#  '50-59',
#  '60-69',
#  '30-39',
#  '30-39',
#  '40-49',
#  '30-39',
#  '40-49',
#  '50-59',
#  '50-59',
#  '60-69',
#  '40-49',
#  '60-69',
#  '40-49',
#  '60-69',
#  '50-59',
#  '30-39',
#  '50-59',
#  '50-59',
#  '60-69',
#  '50-59',
#  '60-69',
#  '30-39',
#  '60-69',
#  '50-59',
#  '50-59',
#  '50-59',
#  '40-49',
#  '40-49',
#  '40-49',
#  '60-69',
#  '60-69',
#  '60-69',
#  '40-49',
#  '40-49',
#  '40-49',
#  '50-59',
#  '40-49',
#  '30-39',
#  '30-39',
#  '60-69',
#  '50-59',
#  '50-59',
#  '40-49',
#  '40-49',
#  '60-69',
#  '50-59',
#  '40-49',
#  '40-49',
#  '40-49',
#  '40-49',
#  '50-59',
#  '50-59',
#  '40-49',
#  '50-59',
#  '60-69',
#  '40-49',
#  '50-59',
#  '40-49',
#  '40-49',
#  '50-59',
#  '30-39',
#  '50-59',
#  '50-59',
#  '50-59',
#  '40-49',
#  '50-59',
#  '50-59',
#  '60-69',
#  '50-59',
#  '40-49',
#  '50-59',
#  '50-59',
#  '30-39',
#  '50-59',
#  '50-59',
#  '50-59',
#  '40-49',
#  '40-49',
#  '50-59',
#  '40-49',
#  '50-59',
#  '60-69',
#  '40-49',
#  '50-59',
#  '40-49',
#  '60-69',
#  '30-39',
#  '40-49',
#  '30-39',
#  '60-69',
#  '60-69',
#  '30-39',
#  '40-49',
#  '40-49',
#  '50-59',
#  '60-69',
#  '60-69',
#  '50-59',
#  '40-49',
#  '30-39',
#  '70-79',
#  '60-69',
#  '50-59',
#  '40-49',
#  '40-49',
#  '30-39',
#  '40-49',
#  '60-69',
#  '40-49',
#  '50-59',
#  '50-59',
#  '40-49',
#  '30-39',
#  '30-39',
#  '50-59',
#  '60-69',
#  '30-39',
#  '40-49',
#  '40-49',
#  '30-39',
#  '60-69',
#  '40-49',
#  '40-49',
#  '40-49',
#  '40-49',
#  '50-59',
#  '50-59',
#  '60-69',
#  '40-49',
#  '60-69',
#  '50-59',
#  '50-59',
#  '30-39',
#  '40-49',
#  '60-69',
#  '30-39',
#  '40-49',
#  '50-59',
#  '50-59',
#  '40-49',
#  '60-69',
#  '60-69',
#  '40-49',
#  '30-39',
#  '60-69',
#  '50-59',
#  '50-59',
#  '50-59',
#  '30-39',
#  '30-39',
#  '60-69',
#  '40-49',
#  '50-59']

# %%
X['menopause'] = X['menopause'].astype('category')
X['menopause'] = X['menopause'].cat.reorder_categories(['lt40', 'ge40', 'premeno'], ordered=True)
X['menopause_cat'] = X['menopause'].cat.codes

# %%
# Out:
#      age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0      1   premeno      30-34       0-2        no          3   left
# 1      2   premeno      20-24       0-2        no          2  right
# 2      2   premeno      20-24       0-2        no          2   left
# 3      4      ge40      15-19       0-2        no          2  right
# 4      2   premeno        0-4       0-2        no          2  right
# 5      4      ge40      15-19       0-2        no          2   left
# 6      3   premeno      25-29       0-2        no          2   left
# 7      4      ge40      20-24       0-2        no          1   left
# 8      2   premeno      50-54       0-2        no          2   left
# 9      2   premeno      20-24       0-2        no          2  right
# 10     2   premeno        0-4       0-2        no          3   left
# 11     3      ge40      25-29       0-2        no          2   left
# 12     4      lt40      10-14       0-2        no          1   left
# 13     3      ge40      25-29       0-2        no          3   left
# 14     2   premeno      30-34       0-2        no          3   left
# 15     4      lt40      30-34       0-2        no          1   left
# 16     2   premeno      15-19       0-2        no          2   left
# 17     3   premeno      30-34       0-2        no          3   left
# 18     4      ge40      30-34       0-2        no          3   left
# 19     3      ge40      30-34       0-2        no          1  right
# 20     3      ge40      40-44       0-2        no          2   left
# 21     4      ge40      15-19       0-2        no          2   left
# 22     1   premeno      25-29       0-2        no          2  right
# 23     3   premeno      40-44       0-2        no          2   left
# 24     3   premeno      35-39       0-2        no          2  right
# 25     2   premeno      25-29       0-2        no          2   left
# 26     3   premeno      20-24       0-2        no          1   left
# 27     4      ge40      25-29       0-2        no          3  right
# 28     2   premeno      40-44       0-2        no          2  right
# 29     4      ge40      30-34       0-2        no          2   left
# ..   ...       ...        ...       ...       ...        ...    ...
# 256    2   premeno      30-34       0-2        no          1   left
# 257    2   premeno      20-24       3-5       yes          2   left
# 258    3      ge40      30-34       6-8       yes          2   left
# 259    3      ge40      30-34       3-5        no          3  right
# 260    4      ge40      25-29       3-5        no          2  right
# 261    2      ge40      25-29     12-14       yes          3   left
# 262    4      ge40      25-29       0-2        no          3   left
# 263    3      lt40      20-24       0-2   unknown          1   left
# 264    3      lt40      20-24       0-2   unknown          1   left
# 265    1   premeno      35-39      9-11       yes          3   left
# 266    2   premeno      30-34       3-5       yes          2   left
# 267    4      ge40      20-24     24-26       yes          3   left
# 268    1   premeno      35-39       0-2        no          3   left
# 269    2   premeno      25-29       0-2        no          2   left
# 270    3      ge40      30-34       6-8       yes          3   left
# 271    3   premeno      25-29       0-2        no          3  right
# 272    2   premeno      15-19       0-2       yes          3  right
# 273    4      ge40      30-34       0-2       yes          2  right
# 274    4      ge40      30-34       3-5       yes          2   left
# 275    2   premeno      25-29      9-11       yes          3  right
# 276    1   premeno      25-29       6-8       yes          3   left
# 277    4      ge40      10-14       6-8       yes          3   left
# 278    3   premeno      35-39     15-17       yes          3  right
# 279    3      ge40      40-44       6-8       yes          3   left
# 280    3      ge40      40-44       6-8       yes          3   left
# 281    1   premeno      30-34       0-2        no          2   left
# 282    1   premeno      20-24       0-2        no          3   left
# 283    4      ge40      20-24       0-2        no          1  right
# 284    2      ge40      30-34       3-5        no          3   left
# 285    3      ge40      30-34       3-5        no          3   left
#
#     breast-quad irradiat  menopause_ge40  menopause_lt40  menopause_premeno  \
# 0      left_low       no               0               0                  1
# 1      right_up       no               0               0                  1
# 2      left_low       no               0               0                  1
# 3       left_up       no               1               0                  0
# 4     right_low       no               0               0                  1
# 5      left_low       no               1               0                  0
# 6      left_low       no               0               0                  1
# 7      left_low       no               1               0                  0
# 8      left_low       no               0               0                  1
# 9       left_up       no               0               0                  1
# 10      central       no               0               0                  1
# 11     left_low       no               1               0                  0
# 12     right_up       no               0               1                  0
# 13     right_up       no               1               0                  0
# 14      left_up       no               0               0                  1
# 15     left_low       no               0               1                  0
# 16     left_low       no               0               0                  1
# 17     left_low       no               0               0                  1
# 18     left_low       no               1               0                  0
# 19     right_up       no               1               0                  0
# 20     left_low       no               1               0                  0
# 21     left_low       no               1               0                  0
# 22     left_low       no               0               0                  1
# 23      left_up       no               0               0                  1
# 24      left_up       no               0               0                  1
# 25      left_up       no               0               0                  1
# 26     left_low       no               0               0                  1
# 27      left_up       no               1               0                  0
# 28     left_low       no               0               0                  1
# 29     left_low       no               1               0                  0
# ..          ...      ...             ...             ...                ...
# 256    left_low      yes               0               0                  1
# 257    left_low      yes               0               0                  1
# 258   right_low      yes               1               0                  0
# 259     left_up       no               1               0                  0
# 260    right_up       no               1               0                  0
# 261   right_low      yes               1               0                  0
# 262     left_up       no               1               0                  0
# 263     left_up       no               0               1                  0
# 264    left_low       no               0               1                  0
# 265    left_low       no               0               0                  1
# 266    right_up       no               0               0                  1
# 267    left_low      yes               1               0                  0
# 268    left_low       no               0               0                  1
# 269    left_low      yes               0               0                  1
# 270   right_low       no               1               0                  0
# 271    left_low      yes               0               0                  1
# 272     left_up       no               0               0                  1
# 273    right_up      yes               1               0                  0
# 274     central      yes               1               0                  0
# 275     left_up       no               0               0                  1
# 276   right_low      yes               0               0                  1
# 277     left_up      yes               1               0                  0
# 278    right_up       no               0               0                  1
# 279    left_low      yes               1               0                  0
# 280    left_low      yes               1               0                  0
# 281     left_up       no               0               0                  1
# 282     left_up      yes               0               0                  1
# 283     left_up       no               1               0                  0
# 284    left_low       no               1               0                  0
# 285    left_low       no               1               0                  0
#
#      menopause_cat
# 0                2
# 1                2
# 2                2
# 3                1
# 4                2
# 5                1
# 6                2
# 7                1
# 8                2
# 9                2
# 10               2
# 11               1
# 12               0
# 13               1
# 14               2
# 15               0
# 16               2
# 17               2
# 18               1
# 19               1
# 20               1
# 21               1
# 22               2
# 23               2
# 24               2
# 25               2
# 26               2
# 27               1
# 28               2
# 29               1
# ..             ...
# 256              2
# 257              2
# 258              1
# 259              1
# 260              1
# 261              1
# 262              1
# 263              0
# 264              0
# 265              2
# 266              2
# 267              1
# 268              2
# 269              2
# 270              1
# 271              2
# 272              2
# 273              1
# 274              1
# 275              2
# 276              2
# 277              1
# 278              2
# 279              1
# 280              1
# 281              2
# 282              2
# 283              1
# 284              1
# 285              1
#
# [286 rows x 13 columns]

# %%
pd.get_dummies(X['breast'],prefix="breast").head(10)
# Out:
#    breast_left  breast_right
# 0            1             0
# 1            0             1
# 2            1             0
# 3            0             1
# 4            0             1
# 5            1             0
# 6            1             0
# 7            1             0
# 8            1             0
# 9            0             1

# %%
X = pd.concat([X,pd.get_dummies(X['breast'],prefix="breast")],axis=1)

# %%
X.head(10)
# Out:
#    age menopause tumor-size inv-nodes node-caps  deg-malig breast breast-quad  \
# 0    1   premeno      30-34       0-2        no          3   left    left_low
# 1    2   premeno      20-24       0-2        no          2  right    right_up
# 2    2   premeno      20-24       0-2        no          2   left    left_low
# 3    4      ge40      15-19       0-2        no          2  right     left_up
# 4    2   premeno        0-4       0-2        no          2  right   right_low
# 5    4      ge40      15-19       0-2        no          2   left    left_low
# 6    3   premeno      25-29       0-2        no          2   left    left_low
# 7    4      ge40      20-24       0-2        no          1   left    left_low
# 8    2   premeno      50-54       0-2        no          2   left    left_low
# 9    2   premeno      20-24       0-2        no          2  right     left_up
#
#   irradiat  menopause_ge40  menopause_lt40  menopause_premeno  menopause_cat  \
# 0       no               0               0                  1              2
# 1       no               0               0                  1              2
# 2       no               0               0                  1              2
# 3       no               1               0                  0              1
# 4       no               0               0                  1              2
# 5       no               1               0                  0              1
# 6       no               0               0                  1              2
# 7       no               1               0                  0              1
# 8       no               0               0                  1              2
# 9       no               0               0                  1              2
#
#    breast_left  breast_right
# 0            1             0
# 1            0             1
# 2            1             0
# 3            0             1
# 4            0             1
# 5            1             0
# 6            1             0
# 7            1             0
# 8            1             0
# 9            0             1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)
